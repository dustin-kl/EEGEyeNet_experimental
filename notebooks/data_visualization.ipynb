# %%
import numpy as np

# %%
data = np.load('./data/LR_task_with_antisaccade_synchronised_min.npz')

# %%
X = data['EEG']

# %%
y = data['labels']

# %%
y
# Out:
# array([[  1,   0],
#        [  1,   1],
#        [  1,   1],
#        ...,
#        [369,   1],
#        [369,   0],
#        [369,   0]])

# %%
import matplotlib.pyplot as plt

# %%
X[0].shape
# Out:
# (500, 129)

# %%
plt.plot(X[2])
plt.show()
plt.savefig('right1')
